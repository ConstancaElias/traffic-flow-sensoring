# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

from sklearn.model_selection import train_test_split, cross_val_score, ShuffleSplit

# %%
convert = pd.read_csv('convertcsv.csv', sep = ',', encoding = 'utf-8')
convert.head()
# Out:
#           timestamp   frc  currentSpeed  freeFlowSpeed  currentTravelTime  \
# 0  29/04/2021 17:52  FRC2            38             49                 91
# 1  29/04/2021 17:59  FRC2            32             48                108
# 2  29/04/2021 18:00  FRC2            31             48                111
# 3  29/04/2021 18:01  FRC2            30             49                115
# 4  29/04/2021 18:02  FRC2            31             48                111
#
#    freeFlowTravelTime  confidence  roadClosure
# 0                  70         1.0        False
# 1                  72         1.0        False
# 2                  72         1.0        False
# 3                  70         1.0        False
# 4                  72         1.0        False

# %%
convert['timestamp'] = convert['timestamp'].apply(lambda x: x[:-3])
convert['timestamp'] = pd.to_datetime(convert['timestamp'])

# %%
convert.head()
# Out:
#             timestamp   frc  currentSpeed  freeFlowSpeed  currentTravelTime  \
# 0 2021-04-29 17:00:00  FRC2            38             49                 91
# 1 2021-04-29 17:00:00  FRC2            32             48                108
# 2 2021-04-29 18:00:00  FRC2            31             48                111
# 3 2021-04-29 18:00:00  FRC2            30             49                115
# 4 2021-04-29 18:00:00  FRC2            31             48                111
#
#    freeFlowTravelTime  confidence  roadClosure
# 0                  70         1.0        False
# 1                  72         1.0        False
# 2                  72         1.0        False
# 3                  70         1.0        False
# 4                  72         1.0        False

# %%
convert.describe()
# Out:
#        currentSpeed  freeFlowSpeed  currentTravelTime  freeFlowTravelTime  \
# count   2714.000000    2714.000000        2714.000000         2714.000000
# mean      45.346721      48.500368          78.165807           71.000737
# std        6.466584       0.503032          15.883786            1.002393
# min       21.000000      48.000000          70.000000           69.000000
# 25%       48.000000      48.000000          70.000000           70.000000
# 50%       48.000000      48.000000          72.000000           72.000000
# 75%       49.000000      49.000000          72.000000           72.000000
# max       49.000000      50.000000         164.000000           72.000000
#
#         confidence
# count  2714.000000
# mean      0.899289
# std       0.171305
# min       0.520000
# 25%       0.940000
# 50%       0.990000
# 75%       1.000000
# max       1.000000

# %%
convert = convert.groupby('timestamp').mean()

# %%
convert.head()
# Out:
#                      currentSpeed  freeFlowSpeed  currentTravelTime  \
# timestamp
# 2021-01-05 09:00:00         49.00          49.00              70.00
# 2021-01-05 10:00:00         47.95          49.00              71.95
# 2021-01-05 11:00:00         47.55          48.65              72.85
# 2021-01-05 12:00:00         48.90          48.90              70.20
# 2021-01-05 13:00:00         48.00          48.00              72.00
#
#                      freeFlowTravelTime  confidence  roadClosure
# timestamp
# 2021-01-05 09:00:00                70.0       0.980        False
# 2021-01-05 10:00:00                70.0       0.981        False
# 2021-01-05 11:00:00                70.7       0.998        False
# 2021-01-05 12:00:00                70.2       1.000        False
# 2021-01-05 13:00:00                72.0       1.000        False

# %%
convert = convert.drop(columns = ['roadClosure'])

# %%
y = convert['currentSpeed']
x = convert.drop(columns = 'currentSpeed')
train_x, test_x, train_y, test_y = train_test_split(x, y, test_size = 0.3, random_state = 40)
train_x
# Out:
#                      freeFlowSpeed  currentTravelTime  freeFlowTravelTime  \
# timestamp
# 2021-02-05 01:00:00          48.50              72.95                71.0
# 2021-04-30 10:00:00          48.35              75.05                71.3
# 2021-04-30 04:00:00          48.00              72.00                72.0
# 2021-01-05 13:00:00          48.00              72.00                72.0
# 2021-06-05 13:00:00          48.05              77.30                71.9
# ...                            ...                ...                 ...
# 2021-04-05 09:00:00          48.60              73.15                70.8
# 2021-01-05 21:00:00          48.90              73.60                70.2
# 2021-03-05 12:00:00          48.20              75.75                71.6
# 2021-01-05 16:00:00          48.20              73.50                71.6
# 2021-04-05 08:00:00          48.30             101.70                71.4
#
#                      confidence
# timestamp
# 2021-02-05 01:00:00      0.8000
# 2021-04-30 10:00:00      0.9960
# 2021-04-30 04:00:00      0.5400
# 2021-01-05 13:00:00      1.0000
# 2021-06-05 13:00:00      1.0000
# ...                         ...
# 2021-04-05 09:00:00      0.9945
# 2021-01-05 21:00:00      0.9970
# 2021-03-05 12:00:00      1.0000
# 2021-01-05 16:00:00      0.9925
# 2021-04-05 08:00:00      0.9985
#
# [98 rows x 4 columns]

# %%
convert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 140 entries, 2021-01-05 09:00:00 to 2021-09-05 10:00:00
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   currentSpeed        140 non-null    float64
#  1   freeFlowSpeed       140 non-null    float64
#  2   currentTravelTime   140 non-null    float64
#  3   freeFlowTravelTime  140 non-null    float64
#  4   confidence          140 non-null    float64
# dtypes: float64(5)
# memory usage: 6.6 KB

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression, LinearRegression

# %%
def linearRegression (X_train, X_test,Y_train, Y_test):
    
    ## criar o modelo de regresssão linear 
    logmodel = LinearRegression()

    # vamos treinar o modelo 
    logmodel.fit(X_train,Y_train)

    logmodel.score(X_train,Y_train)
    #Vamos fazer previsões
    predictions = logmodel.predict(X_test)


    #cf_repost = classification_report(Y_test,predictions)
    #cf_matrix = confusion_matrix(Y_test,predictions )

    accuracy = score(Y_test,predictions)
    #print("The Accuracy for Logistic Regression is {}".format(LRA))

    return cf_repost,cf_matrix, accuracy

# %%
def linearRegression (X_train, X_test,Y_train, Y_test):
    
    linreg = LinearRegression()
    linreg.fit(X_train, y_train)
    y_pred = linreg.predict(X_test)
    print(accuracy_score(y_test, y_pred))  # or you can save it in variable and return it 
    return np.sqrt(metrics.mean_squared_error(y_test, y_pred))

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
linearRegression(train_x, test_x, train_y, test_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5c1e84557ed4> in <module>
#       1 from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
# ----> 2 linearRegression(train_x, test_x, train_y, test_y)
#
# <ipython-input-15-33ac50027a19> in linearRegression(X_train, X_test, Y_train, Y_test)
#       2
#       3     linreg = LinearRegression()
# ----> 4     linreg.fit(X_train, y_train)
#       5     y_pred = linreg.predict(X_test)
#       6     print(accuracy_score(y_test, y_pred))  # or you can save it in variable and return it
#
# NameError: name 'y_train' is not defined
